# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import pickle
from lightgbm import LGBMRegressor

# %%
df=pd.read_csv("dataset.csv", header=0, sep=',', encoding='Latin1',)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head(4)
# Out:
#         dateCrawled                            name  seller offerType  \
# 0  24-03-2016 11:52                      Golf_3_1.6  privat   Angebot
# 1  24-03-2016 10:58            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  14-03-2016 12:52  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  17-03-2016 16:54              GOLF_4_1_4__3TÜRER  privat   Angebot
#
#      price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480.0   test         NaN              1993.0    manuell      0.0   golf
# 1  18300.0   test       coupe              2011.0    manuell    190.0    NaN
# 2   9800.0   test         suv              2004.0  automatik    163.0  grand
# 3   1500.0   test  kleinwagen              2001.0    manuell     75.0   golf
#
#   kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# 0    150000                  0.0   benzin  volkswagen               NaN
# 1    125000                  5.0   diesel        audi                ja
# 2    125000                  8.0   diesel        jeep               NaN
# 3    150000                  6.0   benzin  volkswagen              nein
#
#         dateCreated  nrOfPictures  postalCode          lastSeen
# 0  24-03-2016 00:00           0.0     70435.0  07-04-2016 03:16
# 1  24-03-2016 00:00           0.0     66954.0  07-04-2016 01:46
# 2  14-03-2016 00:00           0.0     90480.0  05-04-2016 12:47
# 3  17-03-2016 00:00           0.0     91074.0  17-03-2016 17:40

# %%
df.shape
# Out:
# (148592, 20)

# %%
print(df.seller.value_counts())
# Out:
# privat        148589
# gewerblich         1
# golf               1
# Name: seller, dtype: int64

# %%
df[df.seller != 'gewerblich']
# Out:
#              dateCrawled                                            name  \
# 0       24-03-2016 11:52                                      Golf_3_1.6
# 1       24-03-2016 10:58                            A5_Sportback_2.7_Tdi
# 2       14-03-2016 12:52                  Jeep_Grand_Cherokee_"Overland"
# 3       17-03-2016 16:54                              GOLF_4_1_4__3TÜRER
# 4       31-03-2016 17:25                  Skoda_Fabia_1.4_TDI_PD_Classic
# ...                  ...                                             ...
# 148587  19-03-2016 20:49  Ford_Focus_Turnier_Titanium_Sport_2.0_TDCi_DPF
# 148588  13-03-2016 14:47                                Ford_ka_mit_tuev
# 148589  17-03-2016 11:49                                         BMW_318
# 148590  16-03-2016 14:55                                    BMW_118d_DPF
# 148591  27-03-2016 19:56                        Ford_Mondeo_Titanium_2.0
#
#         seller offerType    price   abtest vehicleType  yearOfRegistration  \
# 0       privat   Angebot    480.0     test         NaN              1993.0
# 1       privat   Angebot  18300.0     test       coupe              2011.0
# 2       privat   Angebot   9800.0     test         suv              2004.0
# 3       privat   Angebot   1500.0     test  kleinwagen              2001.0
# 4       privat   Angebot   3600.0     test  kleinwagen              2008.0
# ...        ...       ...      ...      ...         ...                 ...
# 148587  privat   Angebot   5550.0  control       kombi              2007.0
# 148588  privat   Angebot    800.0     test         NaN              2016.0
# 148589  privat   Angebot   7800.0  control      cabrio              2003.0
# 148590  privat   Angebot   4000.0     test   limousine              2009.0
# 148591  privat   Angebot   6000.0  control       kombi              2008.0
#
#           gearbox  powerPS   model kilometer  monthOfRegistration fuelType  \
# 0         manuell      0.0    golf    150000                  0.0   benzin
# 1         manuell    190.0     NaN    125000                  5.0   diesel
# 2       automatik    163.0   grand    125000                  8.0   diesel
# 3         manuell     75.0    golf    150000                  6.0   benzin
# 4         manuell     69.0   fabia     90000                  7.0   diesel
# ...           ...      ...     ...       ...                  ...      ...
# 148587    manuell    136.0   focus    150000                 11.0   diesel
# 148588        NaN      0.0     NaN      5000                  0.0   benzin
# 148589    manuell    143.0     3er    150000                 12.0   benzin
# 148590    manuell    143.0     1er     90000                  8.0   diesel
# 148591    manuell      0.0  mondeo    150000                  0.0   diesel
#
#              brand notRepairedDamage       dateCreated  nrOfPictures  \
# 0       volkswagen               NaN  24-03-2016 00:00           0.0
# 1             audi                ja  24-03-2016 00:00           0.0
# 2             jeep               NaN  14-03-2016 00:00           0.0
# 3       volkswagen              nein  17-03-2016 00:00           0.0
# 4            skoda              nein  31-03-2016 00:00           0.0
# ...            ...               ...               ...           ...
# 148587        ford              nein  19-03-2016 00:00           0.0
# 148588        ford               NaN  13-03-2016 00:00           0.0
# 148589         bmw              nein  17-03-2016 00:00           0.0
# 148590         bmw              nein  16-03-2016 00:00           0.0
# 148591        ford               NaN          27-03-20           NaN
#
#         postalCode          lastSeen
# 0          70435.0  07-04-2016 03:16
# 1          66954.0  07-04-2016 01:46
# 2          90480.0  05-04-2016 12:47
# 3          91074.0  17-03-2016 17:40
# 4          60437.0  06-04-2016 10:17
# ...            ...               ...
# 148587     18055.0  07-04-2016 09:16
# 148588     58511.0  06-04-2016 16:17
# 148589     40470.0  06-04-2016 13:46
# 148590     10178.0  16-03-2016 15:44
# 148591         NaN               NaN
#
# [148591 rows x 20 columns]

# %%
df=df.drop('seller',axis=1)

# %%
print(df.offerType.value_counts())
# Out:
# Angebot    148587
# Gesuch          3
# 150000          1
# Name: offerType, dtype: int64

# %%
df[df.offerType != 'Gesuch']
# Out:
#              dateCrawled                                            name  \
# 0       24-03-2016 11:52                                      Golf_3_1.6
# 1       24-03-2016 10:58                            A5_Sportback_2.7_Tdi
# 2       14-03-2016 12:52                  Jeep_Grand_Cherokee_"Overland"
# 3       17-03-2016 16:54                              GOLF_4_1_4__3TÜRER
# 4       31-03-2016 17:25                  Skoda_Fabia_1.4_TDI_PD_Classic
# ...                  ...                                             ...
# 148587  19-03-2016 20:49  Ford_Focus_Turnier_Titanium_Sport_2.0_TDCi_DPF
# 148588  13-03-2016 14:47                                Ford_ka_mit_tuev
# 148589  17-03-2016 11:49                                         BMW_318
# 148590  16-03-2016 14:55                                    BMW_118d_DPF
# 148591  27-03-2016 19:56                        Ford_Mondeo_Titanium_2.0
#
#        offerType    price   abtest vehicleType  yearOfRegistration    gearbox  \
# 0        Angebot    480.0     test         NaN              1993.0    manuell
# 1        Angebot  18300.0     test       coupe              2011.0    manuell
# 2        Angebot   9800.0     test         suv              2004.0  automatik
# 3        Angebot   1500.0     test  kleinwagen              2001.0    manuell
# 4        Angebot   3600.0     test  kleinwagen              2008.0    manuell
# ...          ...      ...      ...         ...                 ...        ...
# 148587   Angebot   5550.0  control       kombi              2007.0    manuell
# 148588   Angebot    800.0     test         NaN              2016.0        NaN
# 148589   Angebot   7800.0  control      cabrio              2003.0    manuell
# 148590   Angebot   4000.0     test   limousine              2009.0    manuell
# 148591   Angebot   6000.0  control       kombi              2008.0    manuell
#
#         powerPS   model kilometer  monthOfRegistration fuelType       brand  \
# 0           0.0    golf    150000                  0.0   benzin  volkswagen
# 1         190.0     NaN    125000                  5.0   diesel        audi
# 2         163.0   grand    125000                  8.0   diesel        jeep
# 3          75.0    golf    150000                  6.0   benzin  volkswagen
# 4          69.0   fabia     90000                  7.0   diesel       skoda
# ...         ...     ...       ...                  ...      ...         ...
# 148587    136.0   focus    150000                 11.0   diesel        ford
# 148588      0.0     NaN      5000                  0.0   benzin        ford
# 148589    143.0     3er    150000                 12.0   benzin         bmw
# 148590    143.0     1er     90000                  8.0   diesel         bmw
# 148591      0.0  mondeo    150000                  0.0   diesel        ford
#
#        notRepairedDamage       dateCreated  nrOfPictures  postalCode  \
# 0                    NaN  24-03-2016 00:00           0.0     70435.0
# 1                     ja  24-03-2016 00:00           0.0     66954.0
# 2                    NaN  14-03-2016 00:00           0.0     90480.0
# 3                   nein  17-03-2016 00:00           0.0     91074.0
# 4                   nein  31-03-2016 00:00           0.0     60437.0
# ...                  ...               ...           ...         ...
# 148587              nein  19-03-2016 00:00           0.0     18055.0
# 148588               NaN  13-03-2016 00:00           0.0     58511.0
# 148589              nein  17-03-2016 00:00           0.0     40470.0
# 148590              nein  16-03-2016 00:00           0.0     10178.0
# 148591               NaN          27-03-20           NaN         NaN
#
#                 lastSeen
# 0       07-04-2016 03:16
# 1       07-04-2016 01:46
# 2       05-04-2016 12:47
# 3       17-03-2016 17:40
# 4       06-04-2016 10:17
# ...                  ...
# 148587  07-04-2016 09:16
# 148588  06-04-2016 16:17
# 148589  06-04-2016 13:46
# 148590  16-03-2016 15:44
# 148591               NaN
#
# [148589 rows x 19 columns]

# %%
df=df.drop('offerType',axis=1)

# %%
print(df.shape)
# Out:
# (148592, 18)

# %%
df=df[(df.powerPS > 50) & (df.powerPS < 900)]

# %%
print(df.shape)
# Out:
# (127746, 18)

# %%
df = df[(df.yearOfRegistration >= 1950) & (df.yearOfRegistration < 2017)]

# %%
df.drop(['name', 'abtest', 'dateCrawled', 'nrOfPictures', 'lastSeen',
         'postalCode','dateCreated'], axis='columns',inplace=True)

# %%
new_df = df.copy()

# %%
new_df = new_df.drop_duplicates ([ 'price', 'vehicleType', 'yearOfRegistration'
                                  ,'gearbox', 'powerPS', 'model', 'kilometer', 'monthOfRegistration', 'fuelType'
                                  ,'notRepairedDamage'])
new_df.gearbox.replace(('manuell', 'automatik'), ('manual', 'automatic'), inplace=True)
new_df.fuelType.replace(('benzin', 'andere', 'elektro'), ('petrol', 'others', 'electric'), inplace=True)
new_df.vehicleType.replace(('kleinwagen', 'cabrio', 'kombi', 'andere'), 
                           ('small car', 'convertible', 'combination', 'others'), inplace=True)
new_df.notRepairedDamage.replace(('ja', 'nein'), ('Yes', 'No'),inplace=True)
new_df = new_df[(new_df.price >= 100) & (new_df.price <= 150000)]
new_df['notRepairedDamage'].fillna(value='not-declared', inplace=True)
new_df[ 'fuelType'].fillna(value='not-declared', inplace=True)
new_df[ 'gearbox'].fillna(value='not-declared', inplace=True)
new_df[ 'vehicleType'].fillna (value='not-declared', inplace=True)
new_df['model'].fillna(value='not-declared',inplace=True)
new_df.to_csv("autos_preprocessed.csv")
labels = ['gearbox', 'notRepairedDamage', 'model', 'brand', 'fuelType', 'vehicleType']
mapper = {}
for i in labels:
    mapper[i]=LabelEncoder()
    mapper[i].fit(new_df[i])
    tr = mapper[i].transform(new_df[i])
    np.save(str('classes'+i+ '.npy'), mapper[i].classes_)
    print(i, ":",mapper[i])
    new_df.loc[:, i + '_labels'] = pd.Series (tr, index=new_df.index)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# gearbox : LabelEncoder()
# notRepairedDamage : LabelEncoder()
# model : LabelEncoder()
# brand : LabelEncoder()
# fuelType : LabelEncoder()
# vehicleType : LabelEncoder()

# %%
labeled=new_df[ ['price'
                 ,'yearOfRegistration'
                 ,'powerPS'
                 ,'kilometer'
                 ,'monthOfRegistration'
                ]
               + [x+"_labels" for x in labels]]
print(labeled.columns)
# Out:
# Index(['price', 'yearOfRegistration', 'powerPS', 'kilometer',
#        'monthOfRegistration', 'gearbox_labels', 'notRepairedDamage_labels',
#        'model_labels', 'brand_labels', 'fuelType_labels',
#        'vehicleType_labels'],
#       dtype='object')

# %%
def find_scores(Y_actual, Y_pred, X_train):
    scores = dict()
    mae = mean_absolute_error(Y_actual, Y_pred)
    mse = mean_squared_error(Y_actual, Y_pred)
    rmse = np.sqrt(mse)
    rmsle = np.log(rmse)
    r2 = r2_score(Y_actual, Y_pred)
    n, k = X_train.shape
    adj_r2_score = 1 - ((1-r2)*(n-1)/(n-k-1))
    
    scores['mae']=mae
    scores['mse']=mse
    scores['rmse']=rmse
    scores['rmsle']=rmsle
    scores['r2']=r2
    scores['adj_r2_score']=adj_r2_score
    
    return scores

# %%
Y = labeled.iloc[:,0].values
X = labeled.iloc[:,1:].values
Y=Y.reshape(-1,1)
from sklearn.model_selection import cross_val_score, train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=3)
model = LGBMRegressor(boosting_type="gbdt",learning_rate=0.07,metric="rmse",n_estimators=300,objective="root_mean_squared_error",random_state=42,reg_sqrt=True)

model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)

find_scores(Y_test, Y_pred, X_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# {'mae': 1347.9571183393216,
#  'mse': 9676457.968437407,
#  'rmse': 3110.7005591084153,
#  'rmsle': 8.042603239969496,
#  'r2': 0.8604813043872556,
#  'adj_r2_score': 0.8604642909495855}

# %%
pickle.dump(model, open('model.sav', 'wb'))
